# %%
import pandas as pd
import xgboost as xgb
import sys
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
train_X = pd.read_csv('../../../data/curated/probability_of_failure/train_X.csv')
train_Y = pd.read_csv('../../../data/curated/probability_of_failure/train_Y.csv')
val_X = pd.read_csv('../../../data/curated/probability_of_failure/val_X.csv')
val_Y = pd.read_csv('../../../data/curated/probability_of_failure/val_Y.csv')
test_X = pd.read_csv('../../../data/curated/probability_of_failure/test_X.csv')
test_Y = pd.read_csv('../../../data/curated/probability_of_failure/test_Y.csv')

# %%
tunable_parameters = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 6, 9],
    'min_child_weight': [1, 5, 10],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'n_estimators': [100, 200, 500],
}
non_tunable_parameters = {
    
}

# %%
sys.path.append('../../../privatePackage')

# %%
from DevinMengTuner import DevinMengTuner

# %%
model = xgb.XGBRegressor(tree_method='gpu_hist', gpu_id=0)

# %%
tuner = DevinMengTuner()
tuner.set_data(train_X=train_X, train_Y=train_Y, test_X=val_X, test_Y=val_Y)
tuner.set_model(model=model, model_name='XGB', model_type='Regression')
tuner.set_parameters(tunable_parameters=tunable_parameters, non_tunable_parameters=non_tunable_parameters)
tuner.tune()
# Out:
# DevinMengTuner initialised
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -33.00024355610298; Root Mean Squared Error: 0.1497669869434616;
#
# Best Performance Metrics:
# R-Squared: -33.00024355610298; Root Mean Squared Error: 0.1497669869434616;
# Already tuned 1 out of 729 in total
# Progress: 0.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9375886302901373; Root Mean Squared Error: 0.057073240390305056;
#
# Best Performance Metrics:
# R-Squared: -3.9375886302901373; Root Mean Squared Error: 0.057073240390305056;
# Already tuned 2 out of 729 in total
# Progress: 0.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5491076450854273; Root Mean Squared Error: 0.017246918631698374;
#
# Best Performance Metrics:
# R-Squared: 0.5491076450854273; Root Mean Squared Error: 0.017246918631698374;
# Already tuned 3 out of 729 in total
# Progress: 0.41%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.982948133635475; Root Mean Squared Error: 0.14972888996924233;
#
# Best Performance Metrics:
# R-Squared: 0.5491076450854273; Root Mean Squared Error: 0.017246918631698374;
# Already tuned 4 out of 729 in total
# Progress: 0.55%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.931257615317369; Root Mean Squared Error: 0.057036638774985264;
#
# Best Performance Metrics:
# R-Squared: 0.5491076450854273; Root Mean Squared Error: 0.017246918631698374;
# Already tuned 5 out of 729 in total
# Progress: 0.69%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5513820165150772; Root Mean Squared Error: 0.01720336556509924;
#
# Best Performance Metrics:
# R-Squared: 0.5513820165150772; Root Mean Squared Error: 0.01720336556509924;
# Already tuned 6 out of 729 in total
# Progress: 0.82%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97592684006764; Root Mean Squared Error: 0.1497134212583478;
#
# Best Performance Metrics:
# R-Squared: 0.5513820165150772; Root Mean Squared Error: 0.01720336556509924;
# Already tuned 7 out of 729 in total
# Progress: 0.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.926657457232638; Root Mean Squared Error: 0.05701002905448391;
#
# Best Performance Metrics:
# R-Squared: 0.5513820165150772; Root Mean Squared Error: 0.01720336556509924;
# Already tuned 8 out of 729 in total
# Progress: 1.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 9 out of 729 in total
# Progress: 1.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.992422217232445; Root Mean Squared Error: 0.14974975992378414;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 10 out of 729 in total
# Progress: 1.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.936455915963184; Root Mean Squared Error: 0.0570666935321128;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 11 out of 729 in total
# Progress: 1.51%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5493260708769674; Root Mean Squared Error: 0.01724274066310342;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 12 out of 729 in total
# Progress: 1.65%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97882285469154; Root Mean Squared Error: 0.14971980170266455;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 13 out of 729 in total
# Progress: 1.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.932387187331228; Root Mean Squared Error: 0.0570431709121095;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 14 out of 729 in total
# Progress: 1.92%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5512871684768386; Root Mean Squared Error: 0.017205184060232324;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 15 out of 729 in total
# Progress: 2.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97263895141167; Root Mean Squared Error: 0.1497061771150022;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 16 out of 729 in total
# Progress: 2.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9281298092042967; Root Mean Squared Error: 0.057018547259674916;
#
# Best Performance Metrics:
# R-Squared: 0.5524571963955129; Root Mean Squared Error: 0.017182737983230695;
# Already tuned 17 out of 729 in total
# Progress: 2.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 18 out of 729 in total
# Progress: 2.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.98686576983811; Root Mean Squared Error: 0.14973752027425452;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 19 out of 729 in total
# Progress: 2.61%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9362122968620437; Root Mean Squared Error: 0.05706528536516567;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 20 out of 729 in total
# Progress: 2.74%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5494125810931151; Root Mean Squared Error: 0.017241085647451675;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 21 out of 729 in total
# Progress: 2.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.976242293280016; Root Mean Squared Error: 0.1497141162720596;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 22 out of 729 in total
# Progress: 3.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.933388135457638; Root Mean Squared Error: 0.057048958612510296;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 23 out of 729 in total
# Progress: 3.16%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5516820442608427; Root Mean Squared Error: 0.0171976119501679;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 24 out of 729 in total
# Progress: 3.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.971211762913285; Root Mean Squared Error: 0.14970303250827297;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 25 out of 729 in total
# Progress: 3.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.929726024027576; Root Mean Squared Error: 0.05702778062864424;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 26 out of 729 in total
# Progress: 3.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5525268950969324; Root Mean Squared Error: 0.017181399942325683;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 27 out of 729 in total
# Progress: 3.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -33.00024355610298; Root Mean Squared Error: 0.1497669869434616;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 28 out of 729 in total
# Progress: 3.84%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9374161680583297; Root Mean Squared Error: 0.05707224364218541;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 29 out of 729 in total
# Progress: 3.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5490165480877396; Root Mean Squared Error: 0.01724866080268478;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 30 out of 729 in total
# Progress: 4.12%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.982948133635475; Root Mean Squared Error: 0.14972888996924233;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 31 out of 729 in total
# Progress: 4.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9313113420253325; Root Mean Squared Error: 0.05703694948502386;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 32 out of 729 in total
# Progress: 4.39%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5513152558677888; Root Mean Squared Error: 0.017204645568507045;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 33 out of 729 in total
# Progress: 4.53%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97592684006764; Root Mean Squared Error: 0.1497134212583478;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 34 out of 729 in total
# Progress: 4.66%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.926664043262524; Root Mean Squared Error: 0.05701006716040389;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 35 out of 729 in total
# Progress: 4.8%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5524268769510878; Root Mean Squared Error: 0.017183320008281672;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 36 out of 729 in total
# Progress: 4.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.992422217232445; Root Mean Squared Error: 0.14974975992378414;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 37 out of 729 in total
# Progress: 5.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.936573423635421; Root Mean Squared Error: 0.05706737273745036;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 38 out of 729 in total
# Progress: 5.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5490971166846406; Root Mean Squared Error: 0.017247119989527722;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 39 out of 729 in total
# Progress: 5.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97882285469154; Root Mean Squared Error: 0.14971980170266455;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 40 out of 729 in total
# Progress: 5.49%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9321723451041075; Root Mean Squared Error: 0.05704192857093975;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 41 out of 729 in total
# Progress: 5.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5512936197539575; Root Mean Squared Error: 0.017205060377777293;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 42 out of 729 in total
# Progress: 5.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97263895141167; Root Mean Squared Error: 0.1497061771150022;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 43 out of 729 in total
# Progress: 5.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.927562035982702; Root Mean Squared Error: 0.05701526259206046;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 44 out of 729 in total
# Progress: 6.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5524317296999799; Root Mean Squared Error: 0.01718322685415907;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 45 out of 729 in total
# Progress: 6.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.98686576983811; Root Mean Squared Error: 0.14973752027425452;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 46 out of 729 in total
# Progress: 6.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.936168995068938; Root Mean Squared Error: 0.057065035068536295;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 47 out of 729 in total
# Progress: 6.45%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5493944930018629; Root Mean Squared Error: 0.017241431701499898;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 48 out of 729 in total
# Progress: 6.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.976242293280016; Root Mean Squared Error: 0.1497141162720596;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 49 out of 729 in total
# Progress: 6.72%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9331971280508897; Root Mean Squared Error: 0.057047854211354485;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 50 out of 729 in total
# Progress: 6.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5516524224719486; Root Mean Squared Error: 0.017198180091159813;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 51 out of 729 in total
# Progress: 7.0%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.971211762913285; Root Mean Squared Error: 0.14970303250827297;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 52 out of 729 in total
# Progress: 7.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9293217747712976; Root Mean Squared Error: 0.05702544237389919;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 53 out of 729 in total
# Progress: 7.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.552550581689119; Root Mean Squared Error: 0.01718094519521916;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 54 out of 729 in total
# Progress: 7.41%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -33.00024355610298; Root Mean Squared Error: 0.1497669869434616;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 55 out of 729 in total
# Progress: 7.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.93766367675655; Root Mean Squared Error: 0.05707367411707575;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 56 out of 729 in total
# Progress: 7.68%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5485927753138313; Root Mean Squared Error: 0.017256762869943463;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 57 out of 729 in total
# Progress: 7.82%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.982948133635475; Root Mean Squared Error: 0.14972888996924233;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 58 out of 729 in total
# Progress: 7.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9313645611434493; Root Mean Squared Error: 0.05703725725792152;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 59 out of 729 in total
# Progress: 8.09%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5508852975465159; Root Mean Squared Error: 0.01721288688864953;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 60 out of 729 in total
# Progress: 8.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97592684006764; Root Mean Squared Error: 0.1497134212583478;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 61 out of 729 in total
# Progress: 8.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9271164154100235; Root Mean Squared Error: 0.057012684466384106;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 62 out of 729 in total
# Progress: 8.5%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5519520408937968; Root Mean Squared Error: 0.01719243259411981;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 63 out of 729 in total
# Progress: 8.64%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.992422217232445; Root Mean Squared Error: 0.14974975992378414;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 64 out of 729 in total
# Progress: 8.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.936663202771312; Root Mean Squared Error: 0.05706789166380656;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 65 out of 729 in total
# Progress: 8.92%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5485941392356488; Root Mean Squared Error: 0.017256736799366974;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 66 out of 729 in total
# Progress: 9.05%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97882285469154; Root Mean Squared Error: 0.14971980170266455;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 67 out of 729 in total
# Progress: 9.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9322628731626583; Root Mean Squared Error: 0.05704245205947514;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 68 out of 729 in total
# Progress: 9.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5508761902782287; Root Mean Squared Error: 0.01721306141153124;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 69 out of 729 in total
# Progress: 9.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.97263895141167; Root Mean Squared Error: 0.1497061771150022;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 70 out of 729 in total
# Progress: 9.6%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9278316541264466; Root Mean Squared Error: 0.05701682240387805;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 71 out of 729 in total
# Progress: 9.74%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5521390747386198; Root Mean Squared Error: 0.017188843801500125;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 72 out of 729 in total
# Progress: 9.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.98686576983811; Root Mean Squared Error: 0.14973752027425452;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 73 out of 729 in total
# Progress: 10.01%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.936264812300605; Root Mean Squared Error: 0.05706558891780246;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 74 out of 729 in total
# Progress: 10.15%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5489175381928669; Root Mean Squared Error: 0.017250554103162802;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 75 out of 729 in total
# Progress: 10.29%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.976242293280016; Root Mean Squared Error: 0.1497141162720596;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 76 out of 729 in total
# Progress: 10.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9334993879513025; Root Mean Squared Error: 0.05704960186243823;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 77 out of 729 in total
# Progress: 10.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5511083982000794; Root Mean Squared Error: 0.017208611050735564;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 78 out of 729 in total
# Progress: 10.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.971211762913285; Root Mean Squared Error: 0.14970303250827297;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 79 out of 729 in total
# Progress: 10.84%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.929604407188836; Root Mean Squared Error: 0.05702707718375275;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 80 out of 729 in total
# Progress: 10.97%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 3; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.552367409072597; Root Mean Squared Error: 0.017184461521917247;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 81 out of 729 in total
# Progress: 11.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.98470385491597; Root Mean Squared Error: 0.14973275777379597;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 82 out of 729 in total
# Progress: 11.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.914032864550074; Root Mean Squared Error: 0.0569369379099506;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 83 out of 729 in total
# Progress: 11.39%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5509084063077008; Root Mean Squared Error: 0.01721244404675739;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 84 out of 729 in total
# Progress: 11.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.96281189971495; Root Mean Squared Error: 0.149684523266616;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 85 out of 729 in total
# Progress: 11.66%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9008070937899886; Root Mean Squared Error: 0.05686026542145254;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 86 out of 729 in total
# Progress: 11.8%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5513147632660975; Root Mean Squared Error: 0.01720465501281654;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 87 out of 729 in total
# Progress: 11.93%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.95740179007684; Root Mean Squared Error: 0.14967260078598274;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 88 out of 729 in total
# Progress: 12.07%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.8978360569914976; Root Mean Squared Error: 0.05684302749014327;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 89 out of 729 in total
# Progress: 12.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5518712189140964; Root Mean Squared Error: 0.01719398316895499;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 90 out of 729 in total
# Progress: 12.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.976371016109155; Root Mean Squared Error: 0.14971439987620552;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 91 out of 729 in total
# Progress: 12.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.912081201042679; Root Mean Squared Error: 0.0569256302139594;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 92 out of 729 in total
# Progress: 12.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5514447997579348; Root Mean Squared Error: 0.017202161733655175;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 93 out of 729 in total
# Progress: 12.76%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.951716371353186; Root Mean Squared Error: 0.1496600705719011;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 94 out of 729 in total
# Progress: 12.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.8985873709714802; Root Mean Squared Error: 0.05684738710151708;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 95 out of 729 in total
# Progress: 13.03%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5516249520795846; Root Mean Squared Error: 0.017198706951950755;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 96 out of 729 in total
# Progress: 13.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.94417915813959; Root Mean Squared Error: 0.14964345753147903;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 97 out of 729 in total
# Progress: 13.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.895507441740283; Root Mean Squared Error: 0.056829513228352245;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 98 out of 729 in total
# Progress: 13.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5519914728448148; Root Mean Squared Error: 0.01719167603886417;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 99 out of 729 in total
# Progress: 13.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.9683506326053; Root Mean Squared Error: 0.14969672821590058;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 100 out of 729 in total
# Progress: 13.72%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.9104729204136293; Root Mean Squared Error: 0.0569163103473167;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 101 out of 729 in total
# Progress: 13.85%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5515978379725621; Root Mean Squared Error: 0.017199226963638944;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 102 out of 729 in total
# Progress: 13.99%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: -32.938905887041344; Root Mean Squared Error: 0.14963183342995523;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 103 out of 729 in total
# Progress: 14.13%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: -3.895241525532329; Root Mean Squared Error: 0.056827969762832435;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 104 out of 729 in total
# Progress: 14.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; max_depth: 6; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.5519491381878695; Root Mean Squared Error: 0.017192488285139213;
#
# Best Performance Metrics:
# R-Squared: 0.5526541453212748; Root Mean Squared Error: 0.017178956787161394;
# Already tuned 105 out of 729 in total
# Progress: 14.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# ...
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 695 out of 729 in total
# Progress: 95.34%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4480317800558318; Root Mean Squared Error: 0.01908236134236672;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 696 out of 729 in total
# Progress: 95.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5174482623938637; Root Mean Squared Error: 0.017842143192267887;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 697 out of 729 in total
# Progress: 95.61%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4878826111305695; Root Mean Squared Error: 0.018380606594809824;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 698 out of 729 in total
# Progress: 95.75%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.45358723845863524; Root Mean Squared Error: 0.018986088262084803;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 699 out of 729 in total
# Progress: 95.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5174676372357381; Root Mean Squared Error: 0.01784178500044502;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 700 out of 729 in total
# Progress: 96.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.49067861229713117; Root Mean Squared Error: 0.018330361731927532;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 701 out of 729 in total
# Progress: 96.16%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 5; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4569406872525813; Root Mean Squared Error: 0.01892773781030792;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 702 out of 729 in total
# Progress: 96.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5135636938190853; Root Mean Squared Error: 0.017913814369254263;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 703 out of 729 in total
# Progress: 96.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4770670382446861; Root Mean Squared Error: 0.018573685487038104;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 704 out of 729 in total
# Progress: 96.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4244566686597372; Root Mean Squared Error: 0.01948561384524113;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 705 out of 729 in total
# Progress: 96.71%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5063180717171885; Root Mean Squared Error: 0.01804673717278634;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 706 out of 729 in total
# Progress: 96.84%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4651483347025678; Root Mean Squared Error: 0.01878415895904;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 707 out of 729 in total
# Progress: 96.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.41486971452021504; Root Mean Squared Error: 0.019647231714978338;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 708 out of 729 in total
# Progress: 97.12%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.49083061178084453; Root Mean Squared Error: 0.018327626314278325;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 709 out of 729 in total
# Progress: 97.26%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.45369915219022194; Root Mean Squared Error: 0.018984143841177685;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 710 out of 729 in total
# Progress: 97.39%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.8; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.39539765851128084; Root Mean Squared Error: 0.019971468099650766;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 711 out of 729 in total
# Progress: 97.53%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5217797716081501; Root Mean Squared Error: 0.017761884835148997;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 712 out of 729 in total
# Progress: 97.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4813097468198152; Root Mean Squared Error: 0.018498185155637004;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 713 out of 729 in total
# Progress: 97.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.428153417924111; Root Mean Squared Error: 0.019422934402663114;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 714 out of 729 in total
# Progress: 97.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5151437691865896; Root Mean Squared Error: 0.017884696271397413;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 715 out of 729 in total
# Progress: 98.08%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4817043657631792; Root Mean Squared Error: 0.01849114711783771;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 716 out of 729 in total
# Progress: 98.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4280448108745727; Root Mean Squared Error: 0.019424778750006578;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 717 out of 729 in total
# Progress: 98.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5143330537112987; Root Mean Squared Error: 0.017899642293704315;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 718 out of 729 in total
# Progress: 98.49%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4789769508018864; Root Mean Squared Error: 0.018539736044536306;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 719 out of 729 in total
# Progress: 98.63%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 0.9; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.42884850117262086; Root Mean Squared Error: 0.019411126461720336;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 720 out of 729 in total
# Progress: 98.77%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5290998009130388; Root Mean Squared Error: 0.017625421660845447;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 721 out of 729 in total
# Progress: 98.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.4994111066279766; Root Mean Squared Error: 0.0181725420893818;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 722 out of 729 in total
# Progress: 99.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.6; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4491102424499914; Root Mean Squared Error: 0.01906371020399623;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 723 out of 729 in total
# Progress: 99.18%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.5256472664617515; Root Mean Squared Error: 0.017689916477007742;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 724 out of 729 in total
# Progress: 99.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.5018840674312672; Root Mean Squared Error: 0.018127599398446333;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 725 out of 729 in total
# Progress: 99.45%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.4477235573039563; Root Mean Squared Error: 0.01908768845800327;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 726 out of 729 in total
# Progress: 99.59%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 100;
#
# Current Performance Metrics:
# R-Squared: 0.51552684631054; Root Mean Squared Error: 0.017877629669620348;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 727 out of 729 in total
# Progress: 99.73%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 200;
#
# Current Performance Metrics:
# R-Squared: 0.48030565104690626; Root Mean Squared Error: 0.018516081163031335;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 728 out of 729 in total
# Progress: 99.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.2; max_depth: 9; min_child_weight: 10; subsample: 1.0; colsample_bytree: 1.0; n_estimators: 500;
#
# Current Performance Metrics:
# R-Squared: 0.43403829043814546; Root Mean Squared Error: 0.019322735250942958;
#
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Already tuned 729 out of 729 in total
# Progress: 100.0%
# ----------------------------
# Best Performance Metrics:
# R-Squared: 0.5621908138958631; Root Mean Squared Error: 0.01699485695222868;
# Best Performance Parameter Combination:
# learning_rate: 0.1; max_depth: 3; min_child_weight: 1; subsample: 1.0; colsample_bytree: 0.8; n_estimators: 200;
