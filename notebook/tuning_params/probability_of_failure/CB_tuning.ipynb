# %%
import pandas as pd
import catboost as cb
import sys
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
train_X = pd.read_csv('../../../data/curated/probability_of_failure/train_X.csv')
train_Y = pd.read_csv('../../../data/curated/probability_of_failure/train_Y.csv')
val_X = pd.read_csv('../../../data/curated/probability_of_failure/val_X.csv')
val_Y = pd.read_csv('../../../data/curated/probability_of_failure/val_Y.csv')
test_X = pd.read_csv('../../../data/curated/probability_of_failure/test_X.csv')
test_Y = pd.read_csv('../../../data/curated/probability_of_failure/test_Y.csv')

# %%
sys.path.append('../../../privatePackage')

# %%
tunable_parameters = {
    'learning_rate': (0.01, 0.05, 0.1),
    'iterations': (500, 2000, 4000, 8000),
    'depth': (4, 8, 12),
    'l2_leaf_reg': (2, 4, 8),
    'random_strength': (2, 4, 8)
}
non_tunable_parameters = {
    'random_state':42
}

# %%
from DevinMengTuner import DevinMengTuner

# %%
model = cb.CatBoostRegressor(task_type='GPU', devices='0', verbose=0)

# %%
tuner = DevinMengTuner()
tuner.set_data(train_X=train_X, train_Y=train_Y, test_X=val_X, test_Y=val_Y)
tuner.set_model(model=model, model_name='CB', model_type='Regression')
tuner.set_parameters(tunable_parameters=tunable_parameters, non_tunable_parameters=non_tunable_parameters)
tuner.tune()
# Out:
# DevinMengTuner initialised
# dir already exist
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 1 out of 324 in total
# Progress: 0.31%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5592502553836041; Root Mean Squared Error: 0.01705183467208388;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 2 out of 324 in total
# Progress: 0.62%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5566202893508341; Root Mean Squared Error: 0.017102633392252216;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 3 out of 324 in total
# Progress: 0.93%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5609618844230624; Root Mean Squared Error: 0.01701869250138585;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 4 out of 324 in total
# Progress: 1.23%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5591993567712847; Root Mean Squared Error: 0.017052819232684594;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 5 out of 324 in total
# Progress: 1.54%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5567627632568165; Root Mean Squared Error: 0.017099885324734537;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 6 out of 324 in total
# Progress: 1.85%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5608863627795422; Root Mean Squared Error: 0.01702015618337064;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 7 out of 324 in total
# Progress: 2.16%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5592317269365078; Root Mean Squared Error: 0.017052193084879454;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 8 out of 324 in total
# Progress: 2.47%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 4; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5567168856872012; Root Mean Squared Error: 0.01710077026942706;
#
# Best Performance Metrics:
# R-Squared: 0.5611279369549338; Root Mean Squared Error: 0.017015473801071844;
# Already tuned 9 out of 324 in total
# Progress: 2.78%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5628765546044694; Root Mean Squared Error: 0.016981542210740507;
#
# Best Performance Metrics:
# R-Squared: 0.5628765546044694; Root Mean Squared Error: 0.016981542210740507;
# Already tuned 10 out of 324 in total
# Progress: 3.09%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5623547581329469; Root Mean Squared Error: 0.016991674664340338;
#
# Best Performance Metrics:
# R-Squared: 0.5628765546044694; Root Mean Squared Error: 0.016981542210740507;
# Already tuned 11 out of 324 in total
# Progress: 3.4%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5613171206124496; Root Mean Squared Error: 0.017011805993501983;
#
# Best Performance Metrics:
# R-Squared: 0.5628765546044694; Root Mean Squared Error: 0.016981542210740507;
# Already tuned 12 out of 324 in total
# Progress: 3.7%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.56293312871371; Root Mean Squared Error: 0.016980443268644098;
#
# Best Performance Metrics:
# R-Squared: 0.56293312871371; Root Mean Squared Error: 0.016980443268644098;
# Already tuned 13 out of 324 in total
# Progress: 4.01%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5623856907001552; Root Mean Squared Error: 0.016991074171800027;
#
# Best Performance Metrics:
# R-Squared: 0.56293312871371; Root Mean Squared Error: 0.016980443268644098;
# Already tuned 14 out of 324 in total
# Progress: 4.32%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5615587336829262; Root Mean Squared Error: 0.017007120557868634;
#
# Best Performance Metrics:
# R-Squared: 0.56293312871371; Root Mean Squared Error: 0.016980443268644098;
# Already tuned 15 out of 324 in total
# Progress: 4.63%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 16 out of 324 in total
# Progress: 4.94%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5628606421888704; Root Mean Squared Error: 0.016981851293793485;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 17 out of 324 in total
# Progress: 5.25%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 8; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5611101168784076; Root Mean Squared Error: 0.01701581924794906;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 18 out of 324 in total
# Progress: 5.56%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5628943832223495; Root Mean Squared Error: 0.01698119590065645;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 19 out of 324 in total
# Progress: 5.86%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5627566872902208; Root Mean Squared Error: 0.016983870377248245;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 20 out of 324 in total
# Progress: 6.17%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5618325876389092; Root Mean Squared Error: 0.017001808335796207;
#
# Best Performance Metrics:
# R-Squared: 0.5630404766545873; Root Mean Squared Error: 0.0169783578582882;
# Already tuned 21 out of 324 in total
# Progress: 6.48%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 22 out of 324 in total
# Progress: 6.79%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5625396923345714; Root Mean Squared Error: 0.016988084229074638;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 23 out of 324 in total
# Progress: 7.1%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5620326796553271; Root Mean Squared Error: 0.016997925898988565;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 24 out of 324 in total
# Progress: 7.41%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5631954607036195; Root Mean Squared Error: 0.016975346586217837;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 25 out of 324 in total
# Progress: 7.72%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5627779804731223; Root Mean Squared Error: 0.016983456825970532;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 26 out of 324 in total
# Progress: 8.02%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 500; depth: 12; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5622023999989592; Root Mean Squared Error: 0.016994632076331;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 27 out of 324 in total
# Progress: 8.33%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5631526869117627; Root Mean Squared Error: 0.016976177715591977;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 28 out of 324 in total
# Progress: 8.64%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5628460302352608; Root Mean Squared Error: 0.01698213511169426;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 29 out of 324 in total
# Progress: 8.95%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5628304476590132; Root Mean Squared Error: 0.016982437777431497;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 30 out of 324 in total
# Progress: 9.26%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5630877785015873; Root Mean Squared Error: 0.016977438860785524;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 31 out of 324 in total
# Progress: 9.57%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.563089322902651; Root Mean Squared Error: 0.016977408854760838;
#
# Best Performance Metrics:
# R-Squared: 0.5633150957592086; Root Mean Squared Error: 0.016973021764215775;
# Already tuned 32 out of 324 in total
# Progress: 9.88%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5633925679929741; Root Mean Squared Error: 0.0169715161062196;
#
# Best Performance Metrics:
# R-Squared: 0.5633925679929741; Root Mean Squared Error: 0.0169715161062196;
# Already tuned 33 out of 324 in total
# Progress: 10.19%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5633430590199888; Root Mean Squared Error: 0.016972478319013544;
#
# Best Performance Metrics:
# R-Squared: 0.5633925679929741; Root Mean Squared Error: 0.0169715161062196;
# Already tuned 34 out of 324 in total
# Progress: 10.49%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5632329077806952; Root Mean Squared Error: 0.016974618925812;
#
# Best Performance Metrics:
# R-Squared: 0.5633925679929741; Root Mean Squared Error: 0.0169715161062196;
# Already tuned 35 out of 324 in total
# Progress: 10.8%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 4; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 36 out of 324 in total
# Progress: 11.11%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5620716288124042; Root Mean Squared Error: 0.016997170055372917;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 37 out of 324 in total
# Progress: 11.42%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.561674854843423; Root Mean Squared Error: 0.017004868240959727;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 38 out of 324 in total
# Progress: 11.73%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5618849866733707; Root Mean Squared Error: 0.01700079170955738;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 39 out of 324 in total
# Progress: 12.04%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.561924029195972; Root Mean Squared Error: 0.017000034181782028;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 40 out of 324 in total
# Progress: 12.35%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5625847178030858; Root Mean Squared Error: 0.016987209959888533;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 41 out of 324 in total
# Progress: 12.65%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5625832842344378; Root Mean Squared Error: 0.01698723779649216;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 42 out of 324 in total
# Progress: 12.96%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5628987687337421; Root Mean Squared Error: 0.01698111071367644;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 43 out of 324 in total
# Progress: 13.27%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5631221136613591; Root Mean Squared Error: 0.01697677175364139;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 44 out of 324 in total
# Progress: 13.58%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 8; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5622732268471611; Root Mean Squared Error: 0.016993257325860798;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 45 out of 324 in total
# Progress: 13.89%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5606787687270143; Root Mean Squared Error: 0.01702417890710305;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 46 out of 324 in total
# Progress: 14.2%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5614508842312265; Root Mean Squared Error: 0.017009212167378874;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 47 out of 324 in total
# Progress: 14.51%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5618201588664209; Root Mean Squared Error: 0.0170020494652176;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 48 out of 324 in total
# Progress: 14.81%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5608171811815498; Root Mean Squared Error: 0.017021496878727317;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 49 out of 324 in total
# Progress: 15.12%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5620055539722424; Root Mean Squared Error: 0.016998452277545293;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 50 out of 324 in total
# Progress: 15.43%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5620620781062081; Root Mean Squared Error: 0.016997355398573964;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 51 out of 324 in total
# Progress: 15.74%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5617709409477604; Root Mean Squared Error: 0.017003004303747547;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 52 out of 324 in total
# Progress: 16.05%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5618749304172876; Root Mean Squared Error: 0.017000986821946593;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 53 out of 324 in total
# Progress: 16.36%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 2000; depth: 12; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5625152301431473; Root Mean Squared Error: 0.016988559197833805;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 54 out of 324 in total
# Progress: 16.67%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.56242621589495; Root Mean Squared Error: 0.01699028742589406;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 55 out of 324 in total
# Progress: 16.98%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5622303664152871; Root Mean Squared Error: 0.016994089260945065;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 56 out of 324 in total
# Progress: 17.28%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5622863014490228; Root Mean Squared Error: 0.016993003535429627;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 57 out of 324 in total
# Progress: 17.59%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5617927287798399; Root Mean Squared Error: 0.017002581621591163;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 58 out of 324 in total
# Progress: 17.9%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.562277594793362; Root Mean Squared Error: 0.016993172540301058;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 59 out of 324 in total
# Progress: 18.21%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5627345136078421; Root Mean Squared Error: 0.016984301018680564;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 60 out of 324 in total
# Progress: 18.52%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5624688128909451; Root Mean Squared Error: 0.01698946041928837;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 61 out of 324 in total
# Progress: 18.83%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5623253406137478; Root Mean Squared Error: 0.01699224572563426;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 62 out of 324 in total
# Progress: 19.14%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 4; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5624890340437521; Root Mean Squared Error: 0.016989067818195192;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 63 out of 324 in total
# Progress: 19.44%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.560092133593344; Root Mean Squared Error: 0.01703554149218222;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 64 out of 324 in total
# Progress: 19.75%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5599660348865085; Root Mean Squared Error: 0.017037982919123038;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 65 out of 324 in total
# Progress: 20.06%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5595733493108187; Root Mean Squared Error: 0.017045583557555248;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 66 out of 324 in total
# Progress: 20.37%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 4; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5595443944492398; Root Mean Squared Error: 0.017046143860161893;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 67 out of 324 in total
# Progress: 20.68%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 4; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5601377970724579; Root Mean Squared Error: 0.01703465730444588;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 68 out of 324 in total
# Progress: 20.99%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 4; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5598178275287009; Root Mean Squared Error: 0.017040851949747;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 69 out of 324 in total
# Progress: 21.3%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 8; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5600211078433619; Root Mean Squared Error: 0.017036916681589215;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 70 out of 324 in total
# Progress: 21.6%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 8; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.5603239902297809; Root Mean Squared Error: 0.01703105154754579;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 71 out of 324 in total
# Progress: 21.91%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 8; l2_leaf_reg: 8; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5595909244751485; Root Mean Squared Error: 0.017045243453339964;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 72 out of 324 in total
# Progress: 22.22%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 12; l2_leaf_reg: 2; random_strength: 2;
#
# Current Performance Metrics:
# R-Squared: 0.5577468120719852; Root Mean Squared Error: 0.017080892705746097;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 73 out of 324 in total
# Progress: 22.53%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 12; l2_leaf_reg: 2; random_strength: 4;
#
# Current Performance Metrics:
# R-Squared: 0.558068350296874; Root Mean Squared Error: 0.017074682282965922;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 74 out of 324 in total
# Progress: 22.84%
# ----------------------------
# Fit succeed.
# Current Parameter Combination:
# learning_rate: 0.01; iterations: 4000; depth: 12; l2_leaf_reg: 2; random_strength: 8;
#
# Current Performance Metrics:
# R-Squared: 0.5581062056582917; Root Mean Squared Error: 0.01707395096839303;
#
# Best Performance Metrics:
# R-Squared: 0.5634013421806263; Root Mean Squared Error: 0.01697134557314539;
# Already tuned 75 out of 324 in total
# Progress: 23.15%
# ----------------------------
